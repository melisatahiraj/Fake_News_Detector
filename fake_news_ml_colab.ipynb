# %%
# Importing Libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from pathlib import Path

# %%
# Reading in the file
file_path = '/content/drive/MyDrive/Colab Notebooks/Project_4/Resources/train.csv'
fake_news_data = pd.read_csv(file_path)
fake_news_data
# Out:
#                ID        label  \
# 0       2635.json        false
# 1      10540.json    half-true
# 2        324.json  mostly-true
# 3       1123.json        false
# 4       9028.json    half-true
# ...           ...          ...
# 11514   3419.json    half-true
# 11515  12548.json  mostly-true
# 11516    401.json         true
# 11517   1055.json        false
# 11518   9117.json  barely-true
#
#                                                statement  \
# 0      Says the Annies List political group supports ...
# 1      When did the decline of coal start? It started...
# 2      Hillary Clinton agrees with John McCain "by vo...
# 3      Health care reform legislation is likely to ma...
# 4      The economic turnaround started at the end of ...
# ...                                                  ...
# 11514  For the first time in more than a decade, impo...
# 11515  Says Donald Trump has bankrupted his companies...
# 11516  John McCain and George Bush have "absolutely n...
# 11517  A new poll shows 62 percent support the presid...
# 11518  No one claims the report vindicating New Jerse...
#
#                                    subject                  speaker  \
# 0                                 abortion             dwayne-bohac
# 1       energy,history,job-accomplishments           scott-surovell
# 2                           foreign-policy             barack-obama
# 3                              health-care             blog-posting
# 4                             economy,jobs            charlie-crist
# ...                                    ...                      ...
# 11514               energy,oil-spill,trade             barack-obama
# 11515                 candidates-biography          hillary-clinton
# 11516                          health-care  campaign-defend-america
# 11517                          health-care  americans-united-change
# 11518  candidates-biography,infrastructure            rudy-giuliani
#
#                   speaker_job        state_info party_affiliation  \
# 0        State representative             Texas        republican
# 1              State delegate          Virginia          democrat
# 2                   President          Illinois          democrat
# 3                         NaN               NaN              none
# 4                         NaN           Florida          democrat
# ...                       ...               ...               ...
# 11514               President          Illinois          democrat
# 11515  Presidential candidate          New York          democrat
# 11516                     NaN  Washington, D.C.              none
# 11517                     NaN               NaN              none
# 11518                Attorney          New York        republican
#
#        barely_true_counts  false_counts  ...  sentiment_score  \
# 0                     0.0           1.0  ...             -0.5
# 1                     0.0           0.0  ...             -0.4
# 2                    70.0          71.0  ...             -0.3
# 3                     7.0          19.0  ...             -0.3
# 4                    15.0           9.0  ...              0.0
# ...                   ...           ...  ...              ...
# 11514                70.0          71.0  ...             -0.2
# 11515                40.0          29.0  ...             -0.7
# 11516                 0.0           1.0  ...             -0.8
# 11517                 1.0           4.0  ...              0.1
# 11518                 9.0          11.0  ...             -0.6
#
#        sentiment_magnitude     anger      fear       joy   disgust       sad  \
# 0                      0.5  0.121137  0.008926  0.026096  0.263479  0.531887
# 1                      0.8  0.095352  0.124566  0.191357  0.016999  0.102045
# 2                      0.3  0.039559  0.024162  0.500384  0.454228  0.052453
# 3                      0.3  0.004804  0.194674  0.375055  0.022509  0.383403
# 4                      0.0  0.044237  0.215996  0.222402  0.045672  0.274343
# ...                    ...       ...       ...       ...       ...       ...
# 11514                  0.2  0.039024  0.103790  0.104699  0.046181  0.758238
# 11515                  0.7  0.064967  0.180882  0.074947  0.054953  0.710395
# 11516                  0.8  0.085547  0.053017  0.248317  0.319548  0.354095
# 11517                  0.5  0.074988  0.148645  0.316695  0.062320  0.169428
# 11518                  0.6  0.137646  0.051547  0.168532  0.564583  0.166095
#
#        speaker_id    list  sentiment_code
# 0             _0_  [0, 1]           _NEG_
# 1             _1_  [0, 1]           _NEG_
# 2             _2_  [1, 0]           _NEG_
# 3             _3_  [0, 1]           _NEG_
# 4             _4_  [0, 1]             NaN
# ...           ...     ...             ...
# 11514         _4_  [0, 1]           _NEG_
# 11515         _8_  [1, 0]           _NEG_
# 11516       _437_  [1, 0]           _NEG_
# 11517       _661_  [0, 1]           _POS_
# 11518        _20_  [0, 1]           _NEG_
#
# [11519 rows x 25 columns]

# %%
# Check for missing values
fake_news_data.isnull().sum()
# Out:
# ID                         0
# label                      0
# statement                  0
# subject                    0
# speaker                    0
# speaker_job             3239
# state_info              2486
# party_affiliation          0
# barely_true_counts         0
# false_counts               0
# half_true_counts           0
# mostly_true_counts         0
# pants_on_fire_counts       0
# context                  112
# sentiment               1541
# sentiment_score            0
# sentiment_magnitude        0
# anger                      0
# fear                       0
# joy                        0
# disgust                    0
# sad                        0
# speaker_id                 0
# list                       0
# sentiment_code          1541
# dtype: int64

# %%
# Drop rows with missing values
fake_news_data.dropna(inplace=True)

# %%
# Check the shape of the data
fake_news_data.shape

fake_news_drop = fake_news_data
fake_news_drop
# Out:
#                ID        label  \
# 0       2635.json        false
# 1      10540.json    half-true
# 2        324.json  mostly-true
# 5      12465.json         true
# 7        153.json    half-true
# ...           ...          ...
# 11511   7013.json  barely-true
# 11513   2661.json   pants-fire
# 11514   3419.json    half-true
# 11515  12548.json  mostly-true
# 11518   9117.json  barely-true
#
#                                                statement  \
# 0      Says the Annies List political group supports ...
# 1      When did the decline of coal start? It started...
# 2      Hillary Clinton agrees with John McCain "by vo...
# 5      The Chicago Bears have had more starting quart...
# 7      I'm the only person on this stage who has work...
# ...                                                  ...
# 11511  Says U.S. Rep. Charles Bass wants to privatize...
# 11513  In the past two years, Democrats have spent mo...
# 11514  For the first time in more than a decade, impo...
# 11515  Says Donald Trump has bankrupted his companies...
# 11518  No one claims the report vindicating New Jerse...
#
#                                    subject            speaker  \
# 0                                 abortion       dwayne-bohac
# 1       energy,history,job-accomplishments     scott-surovell
# 2                           foreign-policy       barack-obama
# 5                                education          robin-vos
# 7                                   ethics       barack-obama
# ...                                    ...                ...
# 11511                      social-security  ann-mclane-kuster
# 11513               federal-budget,history        eric-cantor
# 11514               energy,oil-spill,trade       barack-obama
# 11515                 candidates-biography    hillary-clinton
# 11518  candidates-biography,infrastructure      rudy-giuliani
#
#                       speaker_job     state_info party_affiliation  \
# 0            State representative          Texas        republican
# 1                  State delegate       Virginia          democrat
# 2                       President       Illinois          democrat
# 5      Wisconsin Assembly speaker      Wisconsin        republican
# 7                       President       Illinois          democrat
# ...                           ...            ...               ...
# 11511                    Attorney  New Hampshire          democrat
# 11513       House Majority Leader       Virginia        republican
# 11514                   President       Illinois          democrat
# 11515      Presidential candidate       New York          democrat
# 11518                    Attorney       New York        republican
#
#        barely_true_counts  false_counts  ...  sentiment_score  \
# 0                     0.0           1.0  ...             -0.5
# 1                     0.0           0.0  ...             -0.4
# 2                    70.0          71.0  ...             -0.3
# 5                     0.0           3.0  ...             -0.3
# 7                    70.0          71.0  ...             -0.2
# ...                   ...           ...  ...              ...
# 11511                 2.0           1.0  ...             -0.3
# 11513                 9.0           6.0  ...             -0.5
# 11514                70.0          71.0  ...             -0.2
# 11515                40.0          29.0  ...             -0.7
# 11518                 9.0          11.0  ...             -0.6
#
#        sentiment_magnitude     anger      fear       joy   disgust       sad  \
# 0                      0.5  0.121137  0.008926  0.026096  0.263479  0.531887
# 1                      0.8  0.095352  0.124566  0.191357  0.016999  0.102045
# 2                      0.3  0.039559  0.024162  0.500384  0.454228  0.052453
# 5                      0.3  0.044534  0.037243  0.294698  0.035936  0.598971
# 7                      0.2  0.021023  0.077569  0.032182  0.038037  0.438594
# ...                    ...       ...       ...       ...       ...       ...
# 11511                  0.3  0.151639  0.198275  0.135165  0.106559  0.406074
# 11513                  0.5  0.097422  0.064776  0.088630  0.187085  0.715000
# 11514                  0.2  0.039024  0.103790  0.104699  0.046181  0.758238
# 11515                  0.7  0.064967  0.180882  0.074947  0.054953  0.710395
# 11518                  0.6  0.137646  0.051547  0.168532  0.564583  0.166095
#
#        speaker_id    list  sentiment_code
# 0             _0_  [0, 1]           _NEG_
# 1             _1_  [0, 1]           _NEG_
# 2             _2_  [1, 0]           _NEG_
# 5             _5_  [1, 0]           _NEG_
# 7             _2_  [0, 1]           _NEG_
# ...           ...     ...             ...
# 11511       _240_  [0, 1]           _NEG_
# 11513        _54_  [0, 1]           _NEG_
# 11514         _4_  [0, 1]           _NEG_
# 11515         _8_  [1, 0]           _NEG_
# 11518        _20_  [0, 1]           _NEG_
#
# [6565 rows x 25 columns]

# %%
# Preprocess the 'statement' column (lowercase, remove punctuation, etc.)
# fake_news_drop['statement'] = fake_news_drop['statement'].apply(lambda x: x.lower())
# fake_news_drop.head(10)

# %%
# Analyze the distribution of classes (labels)
fake_news_drop['label'].value_counts()
# Out:
# label
# half-true      1377
# mostly-true    1331
# false          1257
# true           1090
# barely-true    1069
# pants-fire      441
# Name: count, dtype: int64

# %%
# Analyze the distribution of classes (state_info)
fake_news_drop['state_info'].value_counts()
# Out:
# state_info
# Texas             913
# New York          640
# Florida           580
# Wisconsin         534
# Illinois          519
#                  ...
# Virginia            1
# United Kingdom      1
# China               1
# Russia              1
# Mississippi         1
# Name: count, Length: 74, dtype: int64

# %%
# Analyze the distribution of classes (party_affiliation)
fake_news_drop['party_affiliation'].value_counts()
# Out:
# party_affiliation
# republican                      3345
# democrat                        2516
# none                             367
# independent                      123
# libertarian                       32
# newsmaker                         32
# columnist                         27
# activist                          23
# organization                      23
# journalist                        22
# talk-show-host                    14
# state-official                    12
# labor-leader                      12
# business-leader                    6
# tea-party-member                   4
# green                              3
# education-official                 1
# democratic-farmer-labor            1
# ocean-state-tea-party-action       1
# constitution-party                 1
# Name: count, dtype: int64

# %%
# Removing .json after ID
fake_news_drop['ID'] = fake_news_drop['ID'].str.replace('.json', '')
fake_news_drop.head(10)
# Out:
#        ID        label                                          statement  \
# 0    2635        false  Says the Annies List political group supports ...
# 1   10540    half-true  When did the decline of coal start? It started...
# 2     324  mostly-true  Hillary Clinton agrees with John McCain "by vo...
# 5   12465         true  The Chicago Bears have had more starting quart...
# 7     153    half-true  I'm the only person on this stage who has work...
# 9    9741  mostly-true  Says GOP primary opponents Glenn Grothman and ...
# 10   7115  mostly-true  For the first time in history, the share of th...
# 11   4148    half-true  Since 2000, nearly 12 million Americans have s...
# 12   5947        false  When Mitt Romney was governor of Massachusetts...
# 14   8705  barely-true  Most of the (Affordable Care Act) has already ...
#
#                                       subject          speaker  \
# 0                                    abortion     dwayne-bohac
# 1          energy,history,job-accomplishments   scott-surovell
# 2                              foreign-policy     barack-obama
# 5                                   education        robin-vos
# 7                                      ethics     barack-obama
# 9   energy,message-machine-2014,voting-record    duey-stroebel
# 10                                  elections  robert-menendez
# 11    economy,jobs,new-hampshire-2012,poverty         bernie-s
# 12                       history,state-budget      mitt-romney
# 14                                health-care      george-will
#
#                    speaker_job     state_info party_affiliation  \
# 0         State representative          Texas        republican
# 1               State delegate       Virginia          democrat
# 2                    President       Illinois          democrat
# 5   Wisconsin Assembly speaker      Wisconsin        republican
# 7                    President       Illinois          democrat
# 9         State representative      Wisconsin        republican
# 10                U.S. Senator     New Jersey          democrat
# 11                U.S. Senator        Vermont       independent
# 12             Former governor  Massachusetts        republican
# 14                   Columnist       Maryland         columnist
#
#     barely_true_counts  false_counts  ...  sentiment_score  \
# 0                  0.0           1.0  ...             -0.5
# 1                  0.0           0.0  ...             -0.4
# 2                 70.0          71.0  ...             -0.3
# 5                  0.0           3.0  ...             -0.3
# 7                 70.0          71.0  ...             -0.2
# 9                  0.0           0.0  ...             -0.4
# 10                 1.0           3.0  ...             -0.3
# 11                18.0          12.0  ...             -0.8
# 12                34.0          32.0  ...             -0.3
# 14                 7.0           6.0  ...             -0.2
#
#     sentiment_magnitude     anger      fear       joy   disgust       sad  \
# 0                   0.5  0.121137  0.008926  0.026096  0.263479  0.531887
# 1                   0.8  0.095352  0.124566  0.191357  0.016999  0.102045
# 2                   0.3  0.039559  0.024162  0.500384  0.454228  0.052453
# 5                   0.3  0.044534  0.037243  0.294698  0.035936  0.598971
# 7                   0.2  0.021023  0.077569  0.032182  0.038037  0.438594
# 9                   0.4  0.163977  0.101336  0.109979  0.330754  0.203412
# 10                  0.3  0.042787  0.071241  0.448579  0.247391  0.189096
# 11                  0.8  0.260516  0.174539  0.035247  0.115204  0.693537
# 12                  0.3  0.168539  0.084288  0.386121  0.188206  0.239488
# 14                  0.2  0.135979  0.083334  0.115334  0.078517  0.492167
#
#     speaker_id    list  sentiment_code
# 0          _0_  [0, 1]           _NEG_
# 1          _1_  [0, 1]           _NEG_
# 2          _2_  [1, 0]           _NEG_
# 5          _5_  [1, 0]           _NEG_
# 7          _2_  [0, 1]           _NEG_
# 9          _8_  [1, 0]           _NEG_
# 10         _9_  [1, 0]           _NEG_
# 11        _10_  [0, 1]           _NEG_
# 12        _11_  [0, 1]           _NEG_
# 14        _13_  [0, 1]           _NEG_
#
# [10 rows x 25 columns]

# %%
# Split 'subject' column by comma
fake_news_drop['subject'] = fake_news_drop['subject'].str.split(',')

# Explode the resulting list so that each element becomes a separate row
fake_news_subject = fake_news_drop.explode('subject')

# Group by 'subject' and count occurrences
subject_counts = fake_news_subject.groupby('subject').size().reset_index(name='counts')
subject_counts
# Out:
#                subject  counts
# 0    10-news-tampa-bay       2
# 1              Alcohol      15
# 2        abc-news-week      63
# 3             abortion     145
# 4          afghanistan      26
# ..                 ...     ...
# 134             wealth      40
# 135            weather      23
# 136            welfare      32
# 137              women     126
# 138            workers     180
#
# [139 rows x 2 columns]

# %%
# Sort in descending order
subject_counts.sort_values(by='counts', ascending=False)
# Out:
#                subject  counts
# 40             economy     846
# 62         health-care     731
# 122              taxes     639
# 48      federal-budget     513
# 75                jobs     498
# ..                 ...     ...
# 0    10-news-tampa-bay       2
# 32       death-penalty       1
# 46           fake-news       1
# 50               fires       1
# 53                food       1
#
# [139 rows x 2 columns]

# %%
fake_news_drop.dtypes
# Out:
# ID                       object
# label                    object
# statement                object
# subject                  object
# speaker                  object
# speaker_job              object
# state_info               object
# party_affiliation        object
# barely_true_counts      float64
# false_counts            float64
# half_true_counts        float64
# mostly_true_counts      float64
# pants_on_fire_counts    float64
# context                  object
# sentiment                object
# sentiment_score         float64
# sentiment_magnitude     float64
# anger                   float64
# fear                    float64
# joy                     float64
# disgust                 float64
# sad                     float64
# speaker_id               object
# list                     object
# sentiment_code           object
# dtype: object

# %%
# Drop the 'speaker_id' column from the DataFrame
fake_news_drop.drop(columns=['speaker_id'], inplace=True)
fake_news_drop.head()
# Out:
#       ID        label                                          statement  \
# 0   2635        false  Says the Annies List political group supports ...
# 1  10540    half-true  When did the decline of coal start? It started...
# 2    324  mostly-true  Hillary Clinton agrees with John McCain "by vo...
# 5  12465         true  The Chicago Bears have had more starting quart...
# 7    153    half-true  I'm the only person on this stage who has work...
#
#                                   subject         speaker  \
# 0                              [abortion]    dwayne-bohac
# 1  [energy, history, job-accomplishments]  scott-surovell
# 2                        [foreign-policy]    barack-obama
# 5                             [education]       robin-vos
# 7                                [ethics]    barack-obama
#
#                   speaker_job state_info party_affiliation  \
# 0        State representative      Texas        republican
# 1              State delegate   Virginia          democrat
# 2                   President   Illinois          democrat
# 5  Wisconsin Assembly speaker  Wisconsin        republican
# 7                   President   Illinois          democrat
#
#    barely_true_counts  false_counts  ...  sentiment  sentiment_score  \
# 0                 0.0           1.0  ...   NEGATIVE             -0.5
# 1                 0.0           0.0  ...   NEGATIVE             -0.4
# 2                70.0          71.0  ...   NEGATIVE             -0.3
# 5                 0.0           3.0  ...   NEGATIVE             -0.3
# 7                70.0          71.0  ...   NEGATIVE             -0.2
#
#    sentiment_magnitude     anger      fear       joy   disgust       sad  \
# 0                  0.5  0.121137  0.008926  0.026096  0.263479  0.531887
# 1                  0.8  0.095352  0.124566  0.191357  0.016999  0.102045
# 2                  0.3  0.039559  0.024162  0.500384  0.454228  0.052453
# 5                  0.3  0.044534  0.037243  0.294698  0.035936  0.598971
# 7                  0.2  0.021023  0.077569  0.032182  0.038037  0.438594
#
#      list  sentiment_code
# 0  [0, 1]           _NEG_
# 1  [0, 1]           _NEG_
# 2  [1, 0]           _NEG_
# 5  [1, 0]           _NEG_
# 7  [0, 1]           _NEG_
#
# [5 rows x 24 columns]

# %%
# Drop the 'sentiment_code' column from the DataFrame
fake_news_drop.drop(columns=['sentiment_code'], inplace=True)
fake_news_drop.head()
# Out:
#       ID        label                                          statement  \
# 0   2635        false  Says the Annies List political group supports ...
# 1  10540    half-true  When did the decline of coal start? It started...
# 2    324  mostly-true  Hillary Clinton agrees with John McCain "by vo...
# 5  12465         true  The Chicago Bears have had more starting quart...
# 7    153    half-true  I'm the only person on this stage who has work...
#
#                                   subject         speaker  \
# 0                              [abortion]    dwayne-bohac
# 1  [energy, history, job-accomplishments]  scott-surovell
# 2                        [foreign-policy]    barack-obama
# 5                             [education]       robin-vos
# 7                                [ethics]    barack-obama
#
#                   speaker_job state_info party_affiliation  \
# 0        State representative      Texas        republican
# 1              State delegate   Virginia          democrat
# 2                   President   Illinois          democrat
# 5  Wisconsin Assembly speaker  Wisconsin        republican
# 7                   President   Illinois          democrat
#
#    barely_true_counts  false_counts  ...  \
# 0                 0.0           1.0  ...
# 1                 0.0           0.0  ...
# 2                70.0          71.0  ...
# 5                 0.0           3.0  ...
# 7                70.0          71.0  ...
#
#                                     context  sentiment  sentiment_score  \
# 0                                  a mailer   NEGATIVE             -0.5
# 1                           a floor speech.   NEGATIVE             -0.4
# 2                                    Denver   NEGATIVE             -0.3
# 5                 a an online opinion-piece   NEGATIVE             -0.3
# 7  a Democratic debate in Philadelphia, Pa.   NEGATIVE             -0.2
#
#   sentiment_magnitude     anger      fear       joy   disgust       sad  \
# 0                 0.5  0.121137  0.008926  0.026096  0.263479  0.531887
# 1                 0.8  0.095352  0.124566  0.191357  0.016999  0.102045
# 2                 0.3  0.039559  0.024162  0.500384  0.454228  0.052453
# 5                 0.3  0.044534  0.037243  0.294698  0.035936  0.598971
# 7                 0.2  0.021023  0.077569  0.032182  0.038037  0.438594
#
#      list
# 0  [0, 1]
# 1  [0, 1]
# 2  [1, 0]
# 5  [1, 0]
# 7  [0, 1]
#
# [5 rows x 23 columns]

# %%
# Analyze the distribution of classes (speaker_job)
fake_news_drop['speaker_job'].value_counts()
# Out:
# speaker_job
# President                                  467
# U.S. Senator                               457
# Governor                                   365
# President-Elect                            275
# U.S. senator                               248
#                                           ...
# Ohio State University president              1
# Radio personality                            1
# DeKalb County Chief Executive Officer        1
# Human resources director                     1
# Member of the House of Representatinves      1
# Name: count, Length: 974, dtype: int64

# %%
# Analyze the distribution of classes (speaker)
fake_news_drop['speaker'].value_counts()
# Out:
# speaker
# barack-obama           465
# donald-trump           275
# hillary-clinton        231
# mitt-romney            165
# john-mccain            149
#                       ...
# mike-hymes               1
# gloria-romero-roses      1
# charles-odimgbe          1
# gun-owners-america       1
# sal-esquivel             1
# Name: count, Length: 1604, dtype: int64

# %%
# Analyze the distribution of classes (sentiment)
fake_news_drop['sentiment'].value_counts()
# Out:
# sentiment
# NEGATIVE    5589
# POSITIVE     976
# Name: count, dtype: int64

# %%
# fake_news_drop.to_csv("cleaned_data.csv", index=False)
